# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data=pd.read_csv("Titanic_train1.csv")
test=pd.read_csv("Titanic_test1.csv")

# %%
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
train_data.shape
# Out:
# (891, 12)

# %% [markdown]
# # data preprocessing

# %%
train_data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# handeling missing values

# %%
df=data1.dropna(axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df=data1.dropna(axis=1)
#
# NameError: name 'data1' is not defined

# %%
# plotting visualisation

# %%
train_data.hist(bins=20, figsize=(10, 8))  # Note the tuple for figsize
plt.suptitle("Histograms of Numeric Data")  # Use plt.suptitle to set a figure-level title
plt.show()

# %%
train_data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df_num=train_data[["Age","SibSp","Parch","Fare"]]
df_cat = train_data[["Survived", "Sex", "Cabin", "Embarked", "Ticket"]]

# %%
x=pd.DataFrame(
    (
        pd.pivot_table(
            train_data,
            index="Survived",
            columns="Sex",
            values="Ticket",
            aggfunc="count",
        )
    )
)
print()
print(
    pd.pivot_table(
        train_data,
        index="Survived", columns="Pclass", values="Ticket", aggfunc="count"
    )
)
print()
print(
    pd.pivot_table(
        train_data,
        index="Survived",
        columns="Embarked",
        values="Ticket",
        aggfunc="count",
    )
)
print()
# Out:
# Pclass      1   2    3
# Survived
# 0          80  97  372
# 1         136  87  119
#
# Embarked   C   Q    S
# Survived
# 0         75  47  427
# 1         93  30  217

# %%
x
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
pd.pivot_table(train_data,index="Survived",values=("Age","SibSp","Parch","Fare"))
# Out:
#                 Age       Fare     Parch     SibSp
# Survived
# 0         30.415100  22.117887  0.329690  0.553734
# 1         28.549778  48.395408  0.464912  0.473684

# %%
train_data=train_data.drop(columns=["Cabin","Name","Ticket"])

# %%
train_data["Age"]=train_data["Age"].fillna(train_data["Age"].mean())

# %%
train_data["Embarked"]=train_data["Embarked"].fillna(train_data["Embarked"].mode()[0])

# %%
train_data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
train_data["Fare"]=np.log(train_data["Fare"]+1)

# %%
sns.displot(train_data["Fare"],kde=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
cols = ["Sex", "Embarked"]
le = LabelEncoder()
for col in cols:
    train_data[col] = le.fit_transform(train_data[col])

train_data.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch      Fare  Embarked
# 0            1         0       3    1  22.0      1      0  1.134691         2
# 1            2         1       1    0  38.0      1      0  1.664038         0
# 2            3         1       3    0  26.0      0      0  1.159662         2
# 3            4         1       1    0  35.0      1      0  1.607603         2
# 4            5         0       3    1  35.0      0      0  1.164014         2

# %% [markdown]
# # splitting data into Train and test

# %%
train_data[col]
# Out:
# 0      2
# 1      0
# 2      2
# 3      2
# 4      2
#       ..
# 886    2
# 887    2
# 888    2
# 889    0
# 890    1
# Name: Embarked, Length: 891, dtype: int64

# %%
x=train_data.drop(columns=["Survived"],axis=1)
y=train_data["Survived"]

# %%
x
# Out:
#      PassengerId  Pclass  Sex        Age  SibSp  Parch      Fare  Embarked
# 0              1       3    1  22.000000      1      0  1.134691         2
# 1              2       1    0  38.000000      1      0  1.664038         0
# 2              3       3    0  26.000000      0      0  1.159662         2
# 3              4       1    0  35.000000      1      0  1.607603         2
# 4              5       3    1  35.000000      0      0  1.164014         2
# ..           ...     ...  ...        ...    ...    ...       ...       ...
# 886          887       2    1  27.000000      0      0  1.291725         2
# 887          888       1    0  19.000000      0      0  1.489299         2
# 888          889       3    0  29.699118      1      2  1.434282         2
# 889          890       1    1  26.000000      0      0  1.489299         0
# 890          891       3    1  32.000000      0      0  1.153433         1
#
# [891 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split, cross_val_score


def classify (model):
    x_train, x_test, y_train, y_test = train_test_split(
        x, y, test_size=0.25, random_state=40
    )
    model.fit(x_train, y_train)
    print("Accuracy", model.score(x_test, y_test))

    score = cross_val_score(model, x, y, cv=5)
    print("CV SCORE :", np.mean(score))

# %%
#pip install lightgbm

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
classify(model)
# Out:
# Accuracy 0.7443946188340808
# CV SCORE : 0.7633921285543909

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in e:\ldplayer\lib\site-packages (2.1.3)
# Requirement already satisfied: numpy in e:\ldplayer\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in e:\ldplayer\lib\site-packages (from xgboost) (1.13.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBClassifier

# %%
model=XGBClassifier()
classify(model)
# Out:
# Accuracy 0.7892376681614349
# CV SCORE : 0.7801707363002951

# %%
from xgboost import XGBClassifier

model = XGBClassifier()
classify(model)
# Out:
# Accuracy 0.7892376681614349
# CV SCORE : 0.7801707363002951

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
classify(model)
# Out:
# Accuracy 0.8116591928251121
# CV SCORE : 0.8003326847027807

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression(max_iter=1000)
classify(model)
# Out:
# Accuracy 0.8116591928251121
# CV SCORE : 0.7867553825874081

# %%
model = XGBClassifier()
model.fit(x,y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
x_test=test.drop(columns=["PassengerId", "Name", "Cabin", "Ticket"],axis=1)

x_test
# Out:
#      Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0         3    male  34.5      0      0    7.8292        Q
# 1         3  female  47.0      1      0    7.0000        S
# 2         2    male  62.0      0      0    9.6875        Q
# 3         3    male  27.0      0      0    8.6625        S
# 4         3  female  22.0      1      1   12.2875        S
# ..      ...     ...   ...    ...    ...       ...      ...
# 413       3    male   NaN      0      0    8.0500        S
# 414       1  female  39.0      0      0  108.9000        C
# 415       3    male  38.5      0      0    7.2500        S
# 416       3    male   NaN      0      0    8.0500        S
# 417       3    male   NaN      1      1   22.3583        C
#
# [418 rows x 7 columns]

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

cols= ["Sex","Embarked"]
le=LabelEncoder()

for col in cols:
    x_test[col]=le.fit_transform(x_test[col])
    x_test.head()

# %%
x_test["Age"] = x_test["Age"].fillna(x_test["Age"].mean())
x_test["Fare"] = x_test["Fare"].fillna(x_test["Fare"].mean())

# %%
x_test.isnull().sum()
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
x_test = test.drop(columns=["PassengerId", "Name", "Cabin", "Ticket"], axis=1)

x_test["Age"] = x_test["Age"].fillna(x_test["Age"].mean())
x_test["Fare"] = x_test["Fare"].fillna(x_test["Fare"].mean())

x_test.isnull().sum()

from sklearn.preprocessing import LabelEncoder

cols = ["Sex", "Embarked"]
le = LabelEncoder()

for col in cols:
    x_test[col] = le.fit_transform(x_test[col])

x_test.head()
x_test
# Out:
#      Pclass  Sex       Age  SibSp  Parch      Fare  Embarked
# 0         3    1  34.50000      0      0    7.8292         1
# 1         3    0  47.00000      1      0    7.0000         2
# 2         2    1  62.00000      0      0    9.6875         1
# 3         3    1  27.00000      0      0    8.6625         2
# 4         3    0  22.00000      1      1   12.2875         2
# ..      ...  ...       ...    ...    ...       ...       ...
# 413       3    1  30.27259      0      0    8.0500         2
# 414       1    0  39.00000      0      0  108.9000         0
# 415       3    1  38.50000      0      0    7.2500         2
# 416       3    1  30.27259      0      0    8.0500         2
# 417       3    1  30.27259      1      1   22.3583         0
#
# [418 rows x 7 columns]

# %% [markdown]
# according to my analysis when i was used XGBM model accuracy ha incresed
